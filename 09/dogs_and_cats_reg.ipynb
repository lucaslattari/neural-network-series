# %% [markdown]
# # Cats vs Dogs (Kaggle)
# https://www.kaggle.com/c/dogs-vs-cats/

# %% [markdown]
# ## Carregar imagens do diretório

# %%
import os
current_dir = os.path.abspath(os.getcwd())

# %% [markdown]
# ## Converter base de dados para treino, validação e teste

# %%
#cria nova pasta para cachorros e gatos atendendo a estrutura do Keras/Tensorflow
folder = "\\cats_and_dogs_dataset"
train_folder = current_dir + folder + "\\train"
val_folder = current_dir + folder + "\\validation"
test_folder = current_dir + folder + "\\test"

# %% [markdown]
# # Fazer o Tensorflow carregar as imagens para a RNA

# %%
import tensorflow as tf

print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.6.1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(train_folder,
                                             image_size=(180, 180),
                                             batch_size=32)

validation_dataset = image_dataset_from_directory(val_folder,
                                                  image_size=(180, 180),
                                                  batch_size=32)

test_dataset = image_dataset_from_directory(test_folder,
                                            image_size=(180, 180),
                                            batch_size=32)
# Out:
# Found 17501 files belonging to 2 classes.
# Found 2448 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    print(data_batch[0].shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)
# (180, 180, 3)

# %% [markdown]
# # Treinando o modelo

# %%
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom
from tensorflow.keras.layers.experimental.preprocessing import Rescaling

model = keras.Sequential(
    [
        Rescaling(scale=1.0/255),
        RandomFlip("horizontal"),
        RandomRotation(0.1),
        RandomZoom(0.2),
    ]
)

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(1, activation="sigmoid"))

model.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

callbacks = [
    ModelCheckpoint(
        filepath="model_reg.keras",
        save_best_only=True,
        monitor="val_loss"
    )
]

history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 547/547 [==============================] - 172s 299ms/step - loss: 0.6914 - accuracy: 0.5195 - val_loss: 0.6756 - val_accuracy: 0.5833
# Epoch 2/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.6827 - accuracy: 0.5577 - val_loss: 0.6719 - val_accuracy: 0.6164
# Epoch 3/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.6548 - accuracy: 0.6115 - val_loss: 0.6039 - val_accuracy: 0.6969
# Epoch 4/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.6130 - accuracy: 0.6670 - val_loss: 0.5595 - val_accuracy: 0.7132
# Epoch 5/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.5778 - accuracy: 0.7020 - val_loss: 0.5089 - val_accuracy: 0.7475
# Epoch 6/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.5212 - accuracy: 0.7410 - val_loss: 0.4499 - val_accuracy: 0.7851
# Epoch 7/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.4723 - accuracy: 0.7758 - val_loss: 0.4119 - val_accuracy: 0.8113
# Epoch 8/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.4431 - accuracy: 0.7930 - val_loss: 0.3827 - val_accuracy: 0.8370
# Epoch 9/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.4173 - accuracy: 0.8100 - val_loss: 0.3891 - val_accuracy: 0.8280
# Epoch 10/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.3959 - accuracy: 0.8178 - val_loss: 0.3541 - val_accuracy: 0.8460
# Epoch 11/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.3783 - accuracy: 0.8268 - val_loss: 0.3490 - val_accuracy: 0.8489
# Epoch 12/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.3597 - accuracy: 0.8386 - val_loss: 0.3716 - val_accuracy: 0.8415
# Epoch 13/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.3363 - accuracy: 0.8484 - val_loss: 0.3231 - val_accuracy: 0.8607
# Epoch 14/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.3305 - accuracy: 0.8552 - val_loss: 0.3497 - val_accuracy: 0.8533
# Epoch 15/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.3175 - accuracy: 0.8616 - val_loss: 0.2979 - val_accuracy: 0.8803
# Epoch 16/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.2949 - accuracy: 0.8703 - val_loss: 0.3105 - val_accuracy: 0.8709
# Epoch 17/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.2907 - accuracy: 0.8732 - val_loss: 0.3046 - val_accuracy: 0.8758
# Epoch 18/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.2799 - accuracy: 0.8775 - val_loss: 0.3608 - val_accuracy: 0.8599
# Epoch 19/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.2720 - accuracy: 0.8820 - val_loss: 0.2458 - val_accuracy: 0.8962
# Epoch 20/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.2637 - accuracy: 0.8861 - val_loss: 0.2552 - val_accuracy: 0.8901
# Epoch 21/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.2594 - accuracy: 0.8900 - val_loss: 0.2753 - val_accuracy: 0.8975
# Epoch 22/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.2535 - accuracy: 0.8887 - val_loss: 0.2562 - val_accuracy: 0.8934
# Epoch 23/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.2449 - accuracy: 0.8982 - val_loss: 0.2785 - val_accuracy: 0.8877
# Epoch 24/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.2379 - accuracy: 0.8997 - val_loss: 0.2469 - val_accuracy: 0.8950
# Epoch 25/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.2392 - accuracy: 0.8967 - val_loss: 0.2394 - val_accuracy: 0.8979
# Epoch 26/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.2330 - accuracy: 0.9026 - val_loss: 0.2846 - val_accuracy: 0.8930
# Epoch 27/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.2299 - accuracy: 0.9048 - val_loss: 0.2271 - val_accuracy: 0.9089
# Epoch 28/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.2329 - accuracy: 0.9017 - val_loss: 0.2301 - val_accuracy: 0.9036
# Epoch 29/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.2236 - accuracy: 0.9048 - val_loss: 0.2244 - val_accuracy: 0.9060
# Epoch 30/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.2197 - accuracy: 0.9046 - val_loss: 0.2838 - val_accuracy: 0.8922
# Epoch 31/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.2151 - accuracy: 0.9089 - val_loss: 0.2500 - val_accuracy: 0.9073
# Epoch 32/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.2102 - accuracy: 0.9089 - val_loss: 0.2556 - val_accuracy: 0.9056
# Epoch 33/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.2115 - accuracy: 0.9100 - val_loss: 0.2523 - val_accuracy: 0.9060
# Epoch 34/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.2060 - accuracy: 0.9135 - val_loss: 0.2360 - val_accuracy: 0.9118
# Epoch 35/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.2093 - accuracy: 0.9117 - val_loss: 0.2247 - val_accuracy: 0.9150
# Epoch 36/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.2020 - accuracy: 0.9133 - val_loss: 0.2425 - val_accuracy: 0.9036
# Epoch 37/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.2055 - accuracy: 0.9145 - val_loss: 0.1900 - val_accuracy: 0.9289
# Epoch 38/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.2036 - accuracy: 0.9152 - val_loss: 0.2093 - val_accuracy: 0.9183
# Epoch 39/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1902 - accuracy: 0.9197 - val_loss: 0.2021 - val_accuracy: 0.9187
# Epoch 40/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1878 - accuracy: 0.9198 - val_loss: 0.1749 - val_accuracy: 0.9289
# Epoch 41/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1932 - accuracy: 0.9203 - val_loss: 0.1857 - val_accuracy: 0.9261
# Epoch 42/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1888 - accuracy: 0.9209 - val_loss: 0.2611 - val_accuracy: 0.8979
# Epoch 43/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.1908 - accuracy: 0.9234 - val_loss: 0.1909 - val_accuracy: 0.9179
# Epoch 44/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1906 - accuracy: 0.9212 - val_loss: 0.1875 - val_accuracy: 0.9277
# Epoch 45/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1852 - accuracy: 0.9235 - val_loss: 0.1923 - val_accuracy: 0.9244
# Epoch 46/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.1878 - accuracy: 0.9207 - val_loss: 0.2096 - val_accuracy: 0.9154
# Epoch 47/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1824 - accuracy: 0.9227 - val_loss: 0.1908 - val_accuracy: 0.9244
# Epoch 48/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.1859 - accuracy: 0.9219 - val_loss: 0.2281 - val_accuracy: 0.9126
# Epoch 49/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1756 - accuracy: 0.9266 - val_loss: 0.2212 - val_accuracy: 0.9163
# Epoch 50/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1822 - accuracy: 0.9238 - val_loss: 0.2580 - val_accuracy: 0.9056
# Epoch 51/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1787 - accuracy: 0.9273 - val_loss: 0.2151 - val_accuracy: 0.9203
# Epoch 52/100
# 547/547 [==============================] - 28s 52ms/step - loss: 0.1686 - accuracy: 0.9305 - val_loss: 0.1946 - val_accuracy: 0.9293
# Epoch 53/100
# 547/547 [==============================] - 28s 52ms/step - loss: 0.1762 - accuracy: 0.9273 - val_loss: 0.2017 - val_accuracy: 0.9195
# Epoch 54/100
# 547/547 [==============================] - 28s 52ms/step - loss: 0.1736 - accuracy: 0.9280 - val_loss: 0.1914 - val_accuracy: 0.9240
# Epoch 55/100
# 547/547 [==============================] - 28s 52ms/step - loss: 0.1792 - accuracy: 0.9241 - val_loss: 0.2000 - val_accuracy: 0.9183
# Epoch 56/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.1724 - accuracy: 0.9287 - val_loss: 0.2172 - val_accuracy: 0.9203
# Epoch 57/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1662 - accuracy: 0.9316 - val_loss: 0.1877 - val_accuracy: 0.9248
# Epoch 58/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1695 - accuracy: 0.9303 - val_loss: 0.1822 - val_accuracy: 0.9281
# Epoch 59/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1791 - accuracy: 0.9257 - val_loss: 0.1853 - val_accuracy: 0.9236
# Epoch 60/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.1672 - accuracy: 0.9299 - val_loss: 0.1791 - val_accuracy: 0.9273
# Epoch 61/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1715 - accuracy: 0.9292 - val_loss: 0.1674 - val_accuracy: 0.9346
# Epoch 62/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1668 - accuracy: 0.9327 - val_loss: 0.1921 - val_accuracy: 0.9310
# Epoch 63/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1700 - accuracy: 0.9310 - val_loss: 0.1708 - val_accuracy: 0.9306
# Epoch 64/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1579 - accuracy: 0.9349 - val_loss: 0.2004 - val_accuracy: 0.9212
# Epoch 65/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1635 - accuracy: 0.9313 - val_loss: 0.1902 - val_accuracy: 0.9310
# Epoch 66/100
# 547/547 [==============================] - 28s 52ms/step - loss: 0.1640 - accuracy: 0.9323 - val_loss: 0.2010 - val_accuracy: 0.9248
# Epoch 67/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1569 - accuracy: 0.9360 - val_loss: 0.2202 - val_accuracy: 0.9257
# Epoch 68/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1664 - accuracy: 0.9308 - val_loss: 0.1677 - val_accuracy: 0.9400
# Epoch 69/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1570 - accuracy: 0.9349 - val_loss: 0.1832 - val_accuracy: 0.9318
# Epoch 70/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1625 - accuracy: 0.9322 - val_loss: 0.1857 - val_accuracy: 0.9338
# Epoch 71/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1664 - accuracy: 0.9333 - val_loss: 0.1912 - val_accuracy: 0.9330
# Epoch 72/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1596 - accuracy: 0.9352 - val_loss: 0.1812 - val_accuracy: 0.9334
# Epoch 73/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1587 - accuracy: 0.9361 - val_loss: 0.1746 - val_accuracy: 0.9342
# Epoch 74/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1511 - accuracy: 0.9373 - val_loss: 0.1830 - val_accuracy: 0.9326
# Epoch 75/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1611 - accuracy: 0.9349 - val_loss: 0.1685 - val_accuracy: 0.9350
# Epoch 76/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1538 - accuracy: 0.9365 - val_loss: 0.1793 - val_accuracy: 0.9285
# Epoch 77/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1504 - accuracy: 0.9362 - val_loss: 0.1646 - val_accuracy: 0.9371
# Epoch 78/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1537 - accuracy: 0.9391 - val_loss: 0.1762 - val_accuracy: 0.9342
# Epoch 79/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1487 - accuracy: 0.9380 - val_loss: 0.2032 - val_accuracy: 0.9306
# Epoch 80/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1528 - accuracy: 0.9364 - val_loss: 0.1859 - val_accuracy: 0.9297
# Epoch 81/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1522 - accuracy: 0.9381 - val_loss: 0.1722 - val_accuracy: 0.9277
# Epoch 82/100
# 547/547 [==============================] - 27s 49ms/step - loss: 0.1534 - accuracy: 0.9377 - val_loss: 0.1688 - val_accuracy: 0.9334
# Epoch 83/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1571 - accuracy: 0.9371 - val_loss: 0.1989 - val_accuracy: 0.9306
# Epoch 84/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1478 - accuracy: 0.9382 - val_loss: 0.1714 - val_accuracy: 0.9297
# Epoch 85/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1459 - accuracy: 0.9399 - val_loss: 0.1760 - val_accuracy: 0.9404
# Epoch 86/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1561 - accuracy: 0.9382 - val_loss: 0.1882 - val_accuracy: 0.9387
# Epoch 87/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1523 - accuracy: 0.9382 - val_loss: 0.1733 - val_accuracy: 0.9346
# Epoch 88/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1563 - accuracy: 0.9365 - val_loss: 0.1844 - val_accuracy: 0.9252
# Epoch 89/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1489 - accuracy: 0.9411 - val_loss: 0.1852 - val_accuracy: 0.9314
# Epoch 90/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1477 - accuracy: 0.9394 - val_loss: 0.1847 - val_accuracy: 0.9338
# Epoch 91/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1473 - accuracy: 0.9414 - val_loss: 0.1827 - val_accuracy: 0.9330
# Epoch 92/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.1485 - accuracy: 0.9388 - val_loss: 0.1967 - val_accuracy: 0.9306
# Epoch 93/100
# 547/547 [==============================] - 28s 50ms/step - loss: 0.1477 - accuracy: 0.9413 - val_loss: 0.1787 - val_accuracy: 0.9330
# Epoch 94/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1414 - accuracy: 0.9436 - val_loss: 0.1853 - val_accuracy: 0.9330
# Epoch 95/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1468 - accuracy: 0.9391 - val_loss: 0.1773 - val_accuracy: 0.9346
# Epoch 96/100
# 547/547 [==============================] - 27s 50ms/step - loss: 0.1378 - accuracy: 0.9419 - val_loss: 0.1889 - val_accuracy: 0.9334
# Epoch 97/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1427 - accuracy: 0.9429 - val_loss: 0.1809 - val_accuracy: 0.9367
# Epoch 98/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1466 - accuracy: 0.9406 - val_loss: 0.2022 - val_accuracy: 0.9293
# Epoch 99/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1467 - accuracy: 0.9404 - val_loss: 0.1663 - val_accuracy: 0.9359
# Epoch 100/100
# 547/547 [==============================] - 28s 51ms/step - loss: 0.1402 - accuracy: 0.9417 - val_loss: 0.1741 - val_accuracy: 0.9355

# %% [markdown]
# # Visualização de Resultados

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "r", label="Treino acc")
plt.plot(epochs, val_accuracy, "b", label="Val acc")
plt.xlabel("Épocas")
plt.ylabel("%s")
plt.title("Acurácia de Treino e Validação")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r", label="Treino loss")
plt.plot(epochs, val_loss, "b", label="Val loss")
plt.xlabel("Épocas")
plt.ylabel("%s")
plt.title("Loss de Treino e Validação")
plt.legend()
plt.show()

# %% [markdown]
# # Resultados do Conjunto de Teste

# %%
from tensorflow import keras
model = keras.models.load_model("model_reg.keras")

# %%
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 158/158 [==============================] - 37s 219ms/step - loss: 0.1719 - accuracy: 0.9355
# Test accuracy: 0.935

# %% [markdown]
# # Predição Imagem individual

# %%
from matplotlib import pyplot as plt

def showSingleImage(img, title, size):
    fig, axis = plt.subplots(figsize = size)

    axis.imshow(img, 'gray')
    axis.set_title(title, fontdict = {'fontsize': 20, 'fontweight': 'medium'})
    plt.show()

# %%
import cv2
img_name = "ada.jpg"
ada_img = cv2.imread(img_name)
ada_img = cv2.cvtColor(ada_img, cv2.COLOR_BGR2RGB)
#ada_img = cv2.resize(ada_img, (180, 180), interpolation = cv2.INTER_AREA)

showSingleImage(ada_img, "ada", (12, 8))

# %%
from keras.preprocessing import image
import numpy as np

ada_img = image.load_img(img_name, target_size=(180, 180))
x = image.img_to_array(ada_img)
x = np.expand_dims(x, axis=0)
pred=(model.predict(x) > 0.5).astype('int32')[0][0]

if pred == 1:
    print("Cachorro")
else:
    print("Gato")
    
print(model.predict(x))
# Out:
# Cachorro
# [[0.9994282]]

# %% [markdown]
# # Referências
#
# * https://machinelearningmastery.com/how-to-develop-a-convolutional-neural-network-to-classify-photos-of-dogs-and-cats/
# * https://stackoverflow.com/questions/3430372/how-do-i-get-the-full-path-of-the-current-files-directory
# * https://www.geeksforgeeks.org/python-list-files-in-a-directory/
# * https://pynative.com/python-random-sample/
# * https://machinelearningmastery.com/how-to-develop-a-convolutional-neural-network-to-classify-photos-of-dogs-and-cats/
# * https://www.mygreatlearning.com/blog/keras-tutorial/
# * https://www.machinecurve.com/index.php/2020/03/30/how-to-use-conv2d-with-keras/
# * https://www.pyimagesearch.com/2021/06/30/how-to-use-the-modelcheckpoint-callback-with-keras-and-tensorflow/
