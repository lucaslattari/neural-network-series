# %% [markdown]
# # Cats vs Dogs (Kaggle)
# https://www.kaggle.com/c/dogs-vs-cats/

# %% [markdown]
# ## Carregar imagens do diretório

# %%
import os
current_dir = os.path.abspath(os.getcwd())

# %% [markdown]
# ## Converter base de dados para treino, validação e teste

# %%
#cria nova pasta para cachorros e gatos atendendo a estrutura do Keras/Tensorflow
folder = "\\cats_and_dogs_dataset"
train_folder = current_dir + folder + "\\train"
val_folder = current_dir + folder + "\\validation"
test_folder = current_dir + folder + "\\test"

# %% [markdown]
# # Fazer o Tensorflow carregar as imagens para a RNA

# %%
import tensorflow as tf

print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.6.1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(train_folder,
                                             image_size=(180, 180),
                                             batch_size=32)

validation_dataset = image_dataset_from_directory(val_folder,
                                                  image_size=(180, 180),
                                                  batch_size=32)

test_dataset = image_dataset_from_directory(test_folder,
                                            image_size=(180, 180),
                                            batch_size=32)
# Out:
# Found 17501 files belonging to 2 classes.
# Found 2448 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    print(data_batch[0].shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)
# (180, 180, 3)

# %% [markdown]
# # Treinando o modelo

# %%
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.layers.experimental.preprocessing import Rescaling

model = keras.Sequential()
model.add(Rescaling(scale=1.0/255))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(1, activation="sigmoid"))

model.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

callbacks = [
    ModelCheckpoint(
        filepath="model1.keras",
        save_best_only=True,
        monitor="val_loss"
    )
]

history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 547/547 [==============================] - 172s 300ms/step - loss: 0.6971 - accuracy: 0.6135 - val_loss: 0.6110 - val_accuracy: 0.6581
# Epoch 2/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.5705 - accuracy: 0.7030 - val_loss: 0.5595 - val_accuracy: 0.7234
# Epoch 3/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.4847 - accuracy: 0.7645 - val_loss: 0.5321 - val_accuracy: 0.7484
# Epoch 4/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.3705 - accuracy: 0.8350 - val_loss: 0.6210 - val_accuracy: 0.7198
# Epoch 5/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.2488 - accuracy: 0.8972 - val_loss: 0.7286 - val_accuracy: 0.7234
# Epoch 6/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.1563 - accuracy: 0.9410 - val_loss: 0.9430 - val_accuracy: 0.7177
# Epoch 7/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.1034 - accuracy: 0.9643 - val_loss: 1.0622 - val_accuracy: 0.7165
# Epoch 8/30
# 547/547 [==============================] - 22s 39ms/step - loss: 0.0608 - accuracy: 0.9809 - val_loss: 1.3422 - val_accuracy: 0.7165
# Epoch 9/30
# 547/547 [==============================] - 22s 39ms/step - loss: 0.0467 - accuracy: 0.9863 - val_loss: 1.3889 - val_accuracy: 0.7096
# Epoch 10/30
# 547/547 [==============================] - 22s 39ms/step - loss: 0.0446 - accuracy: 0.9884 - val_loss: 1.5345 - val_accuracy: 0.7136
# Epoch 11/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.0431 - accuracy: 0.9871 - val_loss: 1.6749 - val_accuracy: 0.7087
# Epoch 12/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.0320 - accuracy: 0.9902 - val_loss: 1.7647 - val_accuracy: 0.7165
# Epoch 13/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.0253 - accuracy: 0.9934 - val_loss: 1.7587 - val_accuracy: 0.7047
# Epoch 14/30
# 547/547 [==============================] - 22s 39ms/step - loss: 0.0266 - accuracy: 0.9922 - val_loss: 1.8782 - val_accuracy: 0.7083
# Epoch 15/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.0248 - accuracy: 0.9919 - val_loss: 2.0623 - val_accuracy: 0.6936
# Epoch 16/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.0235 - accuracy: 0.9934 - val_loss: 2.0773 - val_accuracy: 0.7034
# Epoch 17/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.0199 - accuracy: 0.9946 - val_loss: 2.2610 - val_accuracy: 0.6998oss: 0.0199 - accuracy: 0.
# Epoch 18/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.0237 - accuracy: 0.9932 - val_loss: 2.2425 - val_accuracy: 0.7006
# Epoch 19/30
# 547/547 [==============================] - 21s 39ms/step - loss: 0.0201 - accuracy: 0.9942 - val_loss: 2.4735 - val_accuracy: 0.7038
# Epoch 20/30
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0176 - accuracy: 0.9942 - val_loss: 2.4689 - val_accuracy: 0.6912
# Epoch 21/30
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0126 - accuracy: 0.9965 - val_loss: 2.6523 - val_accuracy: 0.6932
# Epoch 22/30
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0179 - accuracy: 0.9952 - val_loss: 2.7105 - val_accuracy: 0.7022
# Epoch 23/30
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0147 - accuracy: 0.9956 - val_loss: 2.8761 - val_accuracy: 0.7104
# Epoch 24/30
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0234 - accuracy: 0.9934 - val_loss: 2.6921 - val_accuracy: 0.6969
# Epoch 25/30
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0197 - accuracy: 0.9946 - val_loss: 2.8214 - val_accuracy: 0.7014
# Epoch 26/30
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0124 - accuracy: 0.9965 - val_loss: 2.8907 - val_accuracy: 0.6989
# Epoch 27/30
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0126 - accuracy: 0.9963 - val_loss: 2.9640 - val_accuracy: 0.6916
# Epoch 28/30
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 3.2607 - val_accuracy: 0.7051
# Epoch 29/30
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0195 - accuracy: 0.9948 - val_loss: 3.2432 - val_accuracy: 0.6957
# Epoch 30/30
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0178 - accuracy: 0.9945 - val_loss: 2.9171 - val_accuracy: 0.6957

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 178, 178, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 89, 89, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 87, 87, 64)        18496
# _________________________________________________________________
# flatten (Flatten)            (None, 484416)            0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 484417
# =================================================================
# Total params: 503,809
# Trainable params: 503,809
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Visualização de Resultados

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "r", label="Treino acc")
plt.plot(epochs, val_accuracy, "b", label="Val acc")
plt.xlabel("Épocas")
plt.ylabel("%s")
plt.title("Acurácia de Treino e Validação")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r", label="Treino loss")
plt.plot(epochs, val_loss, "b", label="Val loss")
plt.xlabel("Épocas")
plt.ylabel("%s")
plt.title("Loss de Treino e Validação")
plt.legend()
plt.show()

# %% [markdown]
# # Resultados do Conjunto de Teste

# %%
from tensorflow import keras
model = keras.models.load_model("model1.keras")

# %%
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 158/158 [==============================] - 3s 20ms/step - loss: 0.5550 - accuracy: 0.7218
# Test accuracy: 0.722

# %% [markdown]
# # Predição Imagem individual

# %%
from matplotlib import pyplot as plt

def showSingleImage(img, title, size):
    fig, axis = plt.subplots(figsize = size)

    axis.imshow(img, 'gray')
    axis.set_title(title, fontdict = {'fontsize': 20, 'fontweight': 'medium'})
    plt.show()

# %%
import cv2
ada_img = cv2.imread("ada.jpg")
ada_img = cv2.cvtColor(ada_img, cv2.COLOR_BGR2RGB)
#ada_img = cv2.resize(ada_img, (180, 180), interpolation = cv2.INTER_AREA)

showSingleImage(ada_img, "Ada", (12, 8))

# %%
from keras.preprocessing import image
import numpy as np

ada_img = image.load_img("ada.jpg", target_size=(180, 180))
x = image.img_to_array(ada_img)
x = np.expand_dims(x, axis=0)
pred=(model.predict(x) > 0.5).astype('int32')[0][0]

if pred == 1:
    print("Cachorro")
else:
    print("Gato")
    
print(model.predict(x))
# Out:
# Gato
# [[0.33910534]]

# %% [markdown]
# # Referências
#
# * https://machinelearningmastery.com/how-to-develop-a-convolutional-neural-network-to-classify-photos-of-dogs-and-cats/
# * https://stackoverflow.com/questions/3430372/how-do-i-get-the-full-path-of-the-current-files-directory
# * https://www.geeksforgeeks.org/python-list-files-in-a-directory/
# * https://pynative.com/python-random-sample/
# * https://machinelearningmastery.com/how-to-develop-a-convolutional-neural-network-to-classify-photos-of-dogs-and-cats/
# * https://www.mygreatlearning.com/blog/keras-tutorial/
# * https://www.machinecurve.com/index.php/2020/03/30/how-to-use-conv2d-with-keras/
# * https://www.pyimagesearch.com/2021/06/30/how-to-use-the-modelcheckpoint-callback-with-keras-and-tensorflow/
